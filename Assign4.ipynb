# %% [markdown]
# Decision Tree Classifier Building in Scikit-learn

# %%
#Assignment based on Dicision Tree using python.
#Snehal Hon(145) ,Batch-T3

# %% [markdown]
# Importing Required Libraries

# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %% [markdown]
# Loading Data

# %%
# Load Titanic dataset
titanic = pd.read_csv(r"C:\Users\HP\Downloads\The Titanic dataset.csv")

# %%
titanic.head()
# Out:
#     1       2         3                            4       5    6       7  \
# 0  sn  pclass  survived                          NaN  gender  age  family
# 1   1       3         0                  Mr. Anthony    male   42       0
# 2   1       3         0                  Mr. Anthony    male   42       0
# 3   2       3         0        Master. Eugene Joseph    male    ?       2
# 4   3       2         0  Abbott, Mr. Rossmore Edward     NaN  NaN       2
#
#        8         9         10
# 0   fare  embarked       date
# 1   7.55       NaN  01-Jan-90
# 2   7.55       NaN  01-Jan-90
# 3  20.25         S  02-Jan-90
# 4     **         S  03-Jan-90

# %%
titanic.describe()
# Out:
#            1     2     3                     4     5     6     7     8     9  \
# count   1302  1302  1302                  1301  1301  1045  1300  1300  1296
# unique  1301     4     3                  1297     3    98    10   283     4
# top        1     3     0  Connolly, Miss. Kate  male    24     0    13     S
# freq       2   700   801                     2   835    47   781    59   905
#
#                10
# count        1302
# unique       1301
# top     01-Jan-90
# freq            2

# %% [markdown]
# Feature Selection

# %%
# Rename columns to match feature_cols
titanic.columns = ['sn', 'Pclass', 'Survived', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']

# Replace with actual file name
feature_cols = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']
X = titanic[feature_cols]  # Features
y = titanic['Survived']    # Target variable

# %%
titanic = titanic.drop(index=titanic.index[0])

# %%
titanic.head()
# Out:
#   sn Pclass Survived                         Name     Sex  Age SibSp  Parch  \
# 1  1      3        0                  Mr. Anthony    male   42     0   7.55
# 2  1      3        0                  Mr. Anthony    male   42     0   7.55
# 3  2      3        0        Master. Eugene Joseph    male    ?     2  20.25
# 4  3      2        0  Abbott, Mr. Rossmore Edward     NaN  NaN     2     **
# 5  4      3        1  Abbott, Mr. Rossmore Edward  female   35     2  20.25
#
#   Fare   Embarked
# 1  NaN  01-Jan-90
# 2  NaN  01-Jan-90
# 3    S  02-Jan-90
# 4    S  03-Jan-90
# 5    S  04-Jan-90

# %% [markdown]
# Splitting Data

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %% [markdown]
# Building Decision Tree Model

# %%
# Convert categorical columns to numeric using one-hot encoding
X = pd.get_dummies(titanic[feature_cols], columns=['Sex', 'Embarked'], drop_first=True)

# Convert all columns to numeric, coerce errors to NaN
X = X.apply(pd.to_numeric, errors='coerce')

# Fill NaN values with the mean of the column
X = X.fillna(X.mean())

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# Create and train Decision Tree classifier
clf = DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

# Predict the response for test dataset
y_pred = clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13352\2736386581.py in ?()
#       9
#      10
#      11 # Create and train Decision Tree classifier
#      12 clf = DecisionTreeClassifier()
# ---> 13 clf = clf.fit(X_train, y_train)
#      14
#      15 # Predict the response for test dataset
#      16 y_pred = clf.predict(X_test)
#
# ~\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# ~\AppData\Roaming\Python\Python313\site-packages\sklearn\tree\_classes.py in ?(self, X, y, sample_weight, check_input)
# ...

# %% [markdown]
# Evaluating the Model

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8081841432225064

# %%
print(len(feature_cols))
print(clf.n_features_in_)  
print(clf.classes_)
# Out:
# 7
# 1307
# ['0' '1' 'survived']

# %%
from sklearn.tree import export_graphviz
from io import StringIO  

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, 
                feature_names=X.columns[:clf.n_features_in_],  
                class_names=[str(cls) for cls in clf.classes_])

# %%
from sklearn.tree import DecisionTreeClassifier
print(type(clf))
# Out:
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>

# %%
print(dot_data.getvalue())

# %% [markdown]
# Visualizing Decision Trees

# %%
from sklearn.tree import export_graphviz
from io import StringIO
from IPython.display import Image
import pydotplus

# Generate DOT data
dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, 
                feature_names=X.columns[:clf.n_features_in_],   # Match feature names
                class_names=[str(cls) for cls in clf.classes_]) # Match class names

# Create graph from DOT data
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

# Generate and display the image
if graph:
    graph.write_png('titanic_tree.png')
    display(Image('titanic_tree.png'))
else:
    print("Graph creation failed!")

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(criterion="entropy", max_depth=3)

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8209718670076727
